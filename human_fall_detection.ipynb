# %%
import numpy as np
import pandas as pd
import cv2
import glob
import os
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
import joblib

import mediapipe as mp
import warnings

# %%
def image_to_video(input_path, output_path, fps=18):
    images = sorted(glob.glob(os.path.join(input_path, '*.png'))) # Sort the images in ascending order

    frame = cv2.imread(images[0])
    height, width, layers = frame.shape
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    
    video = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    
    for image in images:
        video.write(cv2.imread(image))
    
    video.release()
    
    print("""Video saved as {}""".format(output_path))

# %%
def concat_csv_files(input_folder):
    combined_df = pd.DataFrame()
    
    for filename in os.listdir(input_folder):
        if filename.endswith('.csv'):
            df = pd.read_csv(os.path.join(input_folder, filename))
            combined_df = pd.concat([combined_df, df], ignore_index=True)
    
    return combined_df

# %%
# Create sequences with a fixed window size
def create_sequences(X, y, window_size):
    Xs, ys = [], []
    for i in range(len(X) - window_size):
        Xs.append(X[i:i+window_size])
        ys.append(y[i+window_size])
    return np.array(Xs), np.array(ys)

# %%
class LSTMModel:
    def __init__(self, input_shape, num_classes):
        self.model = Sequential()
        self.model.add(LSTM(64, input_shape=input_shape, return_sequences=True))
        self.model.add(Dropout(0.2))
        self.model.add(LSTM(32))
        self.model.add(Dropout(0.2))
        self.model.add(Dense(num_classes, activation='softmax'))

    def compile(self):
        self.model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

    def summary(self):
        return self.model.summary()
    
    def fit(self, X_seq, y_seq, epochs=10, batch_size=32, validation_split=0.2, shuffle=True):
        return self.model.fit(X_seq, y_seq, epochs=epochs, batch_size=batch_size, validation_split=validation_split, shuffle=shuffle)
    
    def evaluate(self, X_seq, y_seq):
        return self.model.evaluate(X_seq, y_seq)
    
    def predict(self, X_seq):
        return self.model.predict(X_seq)

# %%
def feature_posses_from_frame(results, mp_pose, frame_count):
    landmarks = results.pose_landmarks.landmark
    
    df = []
    
    # Get coordinates of shoulder, belly, and knees
    lshoulder_x = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].x
    lshoulder_y = landmarks[mp_pose.PoseLandmark.LEFT_SHOULDER.value].y
    lbelly_x = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].x
    lbelly_y = landmarks[mp_pose.PoseLandmark.LEFT_HIP.value].y
    lknee_x = landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].x
    lknee_y = landmarks[mp_pose.PoseLandmark.LEFT_KNEE.value].y
    
    rshoulder_x = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].x
    rshoulder_y = landmarks[mp_pose.PoseLandmark.RIGHT_SHOULDER.value].y
    rbelly_x = landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].x
    rbelly_y = landmarks[mp_pose.PoseLandmark.RIGHT_HIP.value].y
    rknee_x = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].x
    rknee_y = landmarks[mp_pose.PoseLandmark.RIGHT_KNEE.value].y
    
    df.append({"": frame_count,
        'frame': frame_count,
        'lshoulder_x': lshoulder_x,
        'lshoulder_y': lshoulder_y,
        'lbelly_x': lbelly_x,
        'lbelly_y': lbelly_y,
        'lknee_x': lknee_x,
        'lknee_y': lknee_y,
        'rshoulder_x': rshoulder_x,
        'rshoulder_y': rshoulder_y,
        'rbelly_x': rbelly_x,
        'rbelly_y': rbelly_y,
        'rknee_x': rknee_x,
        'rknee_y': rknee_y}) 
    
    df = pd.DataFrame(df)
    
    # adding new columns for difference of previous frames
    for i in range(4):
        for col in [
                'lshoulder_x',
                'lshoulder_y',
                'lbelly_x',
                'lbelly_y',
                'lknee_x',
                'lknee_y',
                'rshoulder_x',
                'rshoulder_y',
                'rbelly_x',
                'rbelly_y',
                'rknee_x',
                'rknee_y'
            ]:
            new_column_name = f'{col}diff_{i+1}frame_before'
            df[new_column_name] = np.nan
                
    return df

# %%
def test_video(input_path, output_path, model):
    cap = cv2.VideoCapture(input_path)
    
    frame_width = int(cap.get(3))
    frame_height = int(cap.get(4))
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    
    
    mp_pose = mp.solutions.pose
    pose = mp_pose.Pose()
    
    frame_queue = []
    
    preds = []
    
    final_data_frame = pd.DataFrame()

    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
    
    output_video = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))
    
    frame_count = 0
    while cap.isOpened():
        ret, frame = cap.read()
        
        if not ret:
            break
        
        # Convert frame to RGB
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        
        # Detect pose
        results = pose.process(rgb_frame)
        
        if results.pose_landmarks is not None:
            # Extract key points
            features = feature_posses_from_frame(results, mp_pose, frame_count)
            
            main_columns = [
                'lshoulder_x',
                'lshoulder_y',
                'lbelly_x',
                'lbelly_y',
                'lknee_x',
                'lknee_y',
                'rshoulder_x',
                'rshoulder_y',
                'rbelly_x',
                'rbelly_y',
                'rknee_x',
                'rknee_y'
            ]
            
            
            # adding previous frames information to the current frame feature matrix
            if frame_count <= 4:
                if frame_count == 0:
                    frame_queue.append(features)
                elif frame_count == 1:
                    for col in main_columns:
                        features[f"{col}diff_1frame_before"] = features[col] - frame_queue[0][col]
                    frame_queue.append(features)
                elif frame_count == 2:
                    for col in main_columns:
                        features[f"{col}diff_1frame_before"] = features[col] - frame_queue[1][col]
                        features[f"{col}diff_2frame_before"] = features[col] - frame_queue[0][col]
                    frame_queue.append(features)
                elif frame_count == 3:
                    for col in main_columns:
                        features[f"{col}diff_1frame_before"] = features[col] - frame_queue[2][col]
                        features[f"{col}diff_2frame_before"] = features[col] - frame_queue[1][col]
                        features[f"{col}diff_3frame_before"] = features[col] - frame_queue[0][col]
                    frame_queue.append(features)
                else:
                    for col in main_columns:
                        features[f"{col}diff_1frame_before"] = features[col] - frame_queue[3][col]
                        features[f"{col}diff_2frame_before"] = features[col] - frame_queue[2][col]
                        features[f"{col}diff_3frame_before"] = features[col] - frame_queue[1][col]
                        features[f"{col}diff_4frame_before"] = features[col] - frame_queue[0][col]
                    frame_queue.append(features)
            else:
                frame_queue.pop(0)
                for col in main_columns:
                    features[f"{col}diff_1frame_before"] = features[col] - frame_queue[3][col]
                    features[f"{col}diff_2frame_before"] = features[col] - frame_queue[2][col]
                    features[f"{col}diff_3frame_before"] = features[col] - frame_queue[1][col]
                    features[f"{col}diff_4frame_before"] = features[col] - frame_queue[0][col]
                frame_queue.append(features)
                
                
            final_data_frame = pd.concat([final_data_frame, features], ignore_index=True)
         
            features = np.array(features)
    
            features = loaded_scaler.transform(features)
            
            seq = []
    
            seq.append(features)
            seq = np.array(seq)
            prediction = model.predict(seq)
            prediction = np.argmax(prediction)
            preds.append(prediction)
            
            label = "no prediction"
            
            if prediction == 0:
                label = "FELL"
            elif prediction == 1:
                label = "IDLE"
            else:
                label = "FALLING"
            
            cv2.putText(frame, label, (50, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 0, 255), 2, cv2.LINE_AA)
            
            output_video.write(frame)
            
            frame_count += 1
    
    
    cap.release()
    output_video.release()
    
    final_data_frame.to_csv(f'{input_path}.csv', index=False)
    
    return preds

# %%
# getting train data


dataset = concat_csv_files("data/labelled")

X = dataset.drop("label", axis=1).values
y = dataset["label"].values

scaler = MinMaxScaler()

X = scaler.fit_transform(X)
y = to_categorical(y+1)


# save scaler
joblib.dump(scaler, 'scaler_params.pkl')

# load scaler
loaded_scaler = joblib.load('scaler_params.pkl')

X_seq, y_seq = create_sequences(X, y, 9)

# %%
warnings.filterwarnings('ignore') 
model = LSTMModel((X_seq.shape[1], X_seq.shape[2]), 3)
model.compile()
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 9, 64)          │        32,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 3)              │            99 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 45,027 (175.89 KB)
#  Trainable params: 45,027 (175.89 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_seq, y_seq, epochs=100, batch_size=128, validation_split=0.2, shuffle=True)
model.model.save('model_saved.keras')
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step - accuracy: 0.4732 - loss: 1.0296 - val_accuracy: 0.4291 - val_loss: 1.1140
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6729 - loss: 0.7784 - val_accuracy: 0.6356 - val_loss: 0.9410
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7470 - loss: 0.5952 - val_accuracy: 0.6481 - val_loss: 1.0909
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7822 - loss: 0.5181 - val_accuracy: 0.6493 - val_loss: 1.2962
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7999 - loss: 0.4868 - val_accuracy: 0.6504 - val_loss: 1.4702
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8367 - loss: 0.4356 - val_accuracy: 0.6629 - val_loss: 1.5514
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8142 - loss: 0.4562 - val_accuracy: 0.6368 - val_loss: 1.4607
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8154 - loss: 0.4571 - val_accuracy: 0.6674 - val_loss: 1.5957
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8145 - loss: 0.4646 - val_accuracy: 0.6549 - val_loss: 1.4975
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8254 - loss: 0.4256 - val_accuracy: 0.6379 - val_loss: 1.5395
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8519 - loss: 0.4095 - val_accuracy: 0.6538 - val_loss: 1.6914
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8333 - loss: 0.4268 - val_accuracy: 0.6549 - val_loss: 1.6831
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8534 - loss: 0.3997 - val_accuracy: 0.6447 - val_loss: 1.6202
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8363 - loss: 0.4149 - val_accuracy: 0.6652 - val_loss: 1.6324
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8512 - loss: 0.3992 - val_accuracy: 0.6561 - val_loss: 1.6464
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8338 - loss: 0.4055 - val_accuracy: 0.6538 - val_loss: 1.5497
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8384 - loss: 0.4146 - val_accuracy: 0.6470 - val_loss: 1.6312
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8368 - loss: 0.4147 - val_accuracy: 0.6470 - val_loss: 1.5743
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8484 - loss: 0.3882 - val_accuracy: 0.6617 - val_loss: 1.7326
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8571 - loss: 0.3705 - val_accuracy: 0.6731 - val_loss: 1.7607
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8570 - loss: 0.3687 - val_accuracy: 0.6561 - val_loss: 1.6529
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8577 - loss: 0.3719 - val_accuracy: 0.6538 - val_loss: 1.6920
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8664 - loss: 0.3590 - val_accuracy: 0.6481 - val_loss: 1.5951
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8577 - loss: 0.3590 - val_accuracy: 0.6617 - val_loss: 1.6621
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8709 - loss: 0.3233 - val_accuracy: 0.6697 - val_loss: 1.7465
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8726 - loss: 0.3322 - val_accuracy: 0.6697 - val_loss: 1.6930
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8647 - loss: 0.3521 - val_accuracy: 0.6652 - val_loss: 1.6908
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8631 - loss: 0.3632 - val_accuracy: 0.6527 - val_loss: 1.6902
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8690 - loss: 0.3394 - val_accuracy: 0.6504 - val_loss: 1.7582
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8524 - loss: 0.3759 - val_accuracy: 0.6674 - val_loss: 1.6924
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8645 - loss: 0.3189 - val_accuracy: 0.6549 - val_loss: 1.7471
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8640 - loss: 0.3644 - val_accuracy: 0.6640 - val_loss: 1.6454
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8687 - loss: 0.3468 - val_accuracy: 0.6629 - val_loss: 1.6387
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8697 - loss: 0.3334 - val_accuracy: 0.6572 - val_loss: 1.6382
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8894 - loss: 0.2988 - val_accuracy: 0.6595 - val_loss: 1.7127
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8742 - loss: 0.3235 - val_accuracy: 0.5857 - val_loss: 1.6679
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8613 - loss: 0.3448 - val_accuracy: 0.6617 - val_loss: 1.7167
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8824 - loss: 0.3098 - val_accuracy: 0.6561 - val_loss: 1.7406
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8552 - loss: 0.3551 - val_accuracy: 0.6368 - val_loss: 1.7120
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8828 - loss: 0.3083 - val_accuracy: 0.6436 - val_loss: 1.7409
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8899 - loss: 0.2945 - val_accuracy: 0.6390 - val_loss: 1.7041
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8761 - loss: 0.3074 - val_accuracy: 0.6504 - val_loss: 1.7586
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8687 - loss: 0.3338 - val_accuracy: 0.6527 - val_loss: 1.7816
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8806 - loss: 0.2864 - val_accuracy: 0.6266 - val_loss: 1.7692
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8714 - loss: 0.3253 - val_accuracy: 0.6232 - val_loss: 1.7760
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8751 - loss: 0.3170 - val_accuracy: 0.5925 - val_loss: 1.7599
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8810 - loss: 0.2920 - val_accuracy: 0.6345 - val_loss: 1.7984
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8885 - loss: 0.2850 - val_accuracy: 0.6266 - val_loss: 1.8007
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8921 - loss: 0.2824 - val_accuracy: 0.6220 - val_loss: 1.8150
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8864 - loss: 0.2948 - val_accuracy: 0.6379 - val_loss: 1.7900
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8771 - loss: 0.3260 - val_accuracy: 0.6243 - val_loss: 1.7963
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8886 - loss: 0.2860 - val_accuracy: 0.6186 - val_loss: 1.7895
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8905 - loss: 0.2930 - val_accuracy: 0.6368 - val_loss: 1.7972
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8931 - loss: 0.2797 - val_accuracy: 0.6527 - val_loss: 1.8308
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8877 - loss: 0.3061 - val_accuracy: 0.6073 - val_loss: 1.8227
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8909 - loss: 0.2862 - val_accuracy: 0.6413 - val_loss: 1.7703
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8875 - loss: 0.2921 - val_accuracy: 0.6175 - val_loss: 1.8266
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9010 - loss: 0.2525 - val_accuracy: 0.6186 - val_loss: 1.7905
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9010 - loss: 0.2629 - val_accuracy: 0.6402 - val_loss: 1.7823
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8876 - loss: 0.2942 - val_accuracy: 0.6152 - val_loss: 1.7734
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8851 - loss: 0.3009 - val_accuracy: 0.6163 - val_loss: 1.8109
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8957 - loss: 0.2695 - val_accuracy: 0.6413 - val_loss: 1.8096
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8868 - loss: 0.3027 - val_accuracy: 0.6175 - val_loss: 1.8252
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9044 - loss: 0.2755 - val_accuracy: 0.6095 - val_loss: 1.8213
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8880 - loss: 0.2924 - val_accuracy: 0.5834 - val_loss: 1.8264
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8736 - loss: 0.3171 - val_accuracy: 0.5505 - val_loss: 1.8936
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8972 - loss: 0.2706 - val_accuracy: 0.5959 - val_loss: 1.8370
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8939 - loss: 0.2712 - val_accuracy: 0.6186 - val_loss: 1.8479
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8847 - loss: 0.2860 - val_accuracy: 0.6073 - val_loss: 1.8211
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8955 - loss: 0.2743 - val_accuracy: 0.5914 - val_loss: 1.8695
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8911 - loss: 0.3002 - val_accuracy: 0.5562 - val_loss: 1.8645
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.8936 - loss: 0.2754 - val_accuracy: 0.5664 - val_loss: 1.8476
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9020 - loss: 0.2659 - val_accuracy: 0.6084 - val_loss: 1.8350
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8914 - loss: 0.2978 - val_accuracy: 0.5437 - val_loss: 1.9002
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8922 - loss: 0.2833 - val_accuracy: 0.6118 - val_loss: 1.8733
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8960 - loss: 0.2766 - val_accuracy: 0.6243 - val_loss: 1.8715
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8839 - loss: 0.2848 - val_accuracy: 0.5970 - val_loss: 1.8464
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8936 - loss: 0.2749 - val_accuracy: 0.6186 - val_loss: 1.8416
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8913 - loss: 0.2775 - val_accuracy: 0.6152 - val_loss: 1.8364
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8942 - loss: 0.2842 - val_accuracy: 0.6027 - val_loss: 1.7507
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8844 - loss: 0.2897 - val_accuracy: 0.6118 - val_loss: 1.8184
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8884 - loss: 0.2778 - val_accuracy: 0.6175 - val_loss: 1.8226
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8939 - loss: 0.2753 - val_accuracy: 0.5868 - val_loss: 1.8384
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8861 - loss: 0.2834 - val_accuracy: 0.5846 - val_loss: 1.8602
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9020 - loss: 0.2729 - val_accuracy: 0.6073 - val_loss: 1.8769
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8827 - loss: 0.2839 - val_accuracy: 0.5891 - val_loss: 1.8493
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8863 - loss: 0.2923 - val_accuracy: 0.6186 - val_loss: 1.8441
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8964 - loss: 0.2486 - val_accuracy: 0.6050 - val_loss: 1.8767
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8799 - loss: 0.3042 - val_accuracy: 0.6232 - val_loss: 1.8423
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8276 - loss: 0.4334 - val_accuracy: 0.5142 - val_loss: 1.9328
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9059 - loss: 0.2753 - val_accuracy: 0.5494 - val_loss: 1.9148
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8995 - loss: 0.2614 - val_accuracy: 0.5743 - val_loss: 1.8995
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8981 - loss: 0.2702 - val_accuracy: 0.5516 - val_loss: 1.8973
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9019 - loss: 0.2630 - val_accuracy: 0.5380 - val_loss: 1.9401
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9005 - loss: 0.2728 - val_accuracy: 0.5812 - val_loss: 1.9288
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8948 - loss: 0.2727 - val_accuracy: 0.5868 - val_loss: 1.8941
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8972 - loss: 0.2617 - val_accuracy: 0.5925 - val_loss: 1.9079
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.8996 - loss: 0.2603 - val_accuracy: 0.5880 - val_loss: 1.9165
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9075 - loss: 0.2477 - val_accuracy: 0.5857 - val_loss: 1.9131
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.8961 - loss: 0.2628 - val_accuracy: 0.5460 - val_loss: 2.0153

# %%
from tensorflow.keras.models import load_model
loaded_model=load_model("model_saved.keras")
prediction=test_video("data/input.mp4", "data/output.mp4", loaded_model)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
